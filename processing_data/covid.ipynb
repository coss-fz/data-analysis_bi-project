# %% [markdown]
# Import Libraries and Packages

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

####import sys
####sys.path.append("../")

from package_module.functions import DataAnalyzer

# %%
class_instance = DataAnalyzer(pd.read_csv("../assets_data/covid_19_data.csv"))
df_covid = class_instance.df

df_covid['date']= pd.to_datetime(df_covid['date'])

df_covid.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan 2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan 2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan 2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan 2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
##Basic (preliminary) information about the dataframe
print(df_covid.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321904 entries, 0 to 321903
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    321904 non-null  object
#  1   continent                                   306628 non-null  object
#  2   location                                    321904 non-null  object
#  3   date                                        321904 non-null  datetime64[ns]
#  4   total_cases                                 284841 non-null  float64
#  5   new_cases                                   313024 non-null  float64
#  6   new_cases_smoothed                          311765 non-null  float64
#  7   total_deaths                                263845 non-null  float64
#  8   new_deaths                                  313099 non-null  float64
# ...

# %%
#Statistical Information
print(df_covid.describe())
# Out:
#                                 date   total_cases     new_cases  \
# count                         321904  2.848410e+05  3.130240e+05
# mean   2021-10-01 02:57:47.677319680  6.039621e+06  1.039078e+04
# min              2020-01-01 00:00:00  1.000000e+00  0.000000e+00
# 25%              2020-11-18 00:00:00  7.144000e+03  0.000000e+00
# 50%              2021-10-02 00:00:00  6.343800e+04  5.000000e+00
# 75%              2022-08-14 00:00:00  6.651880e+05  3.440000e+02
# max              2023-06-28 00:00:00  7.675180e+08  8.401710e+06
# std                              NaN  3.743113e+07  1.149393e+05
#
#        new_cases_smoothed  total_deaths     new_deaths  new_deaths_smoothed  \
# count        3.117650e+05  2.638450e+05  313099.000000        311869.000000
# mean         1.043132e+04  8.236171e+04      92.787703            93.143020
# min          0.000000e+00  1.000000e+00       0.000000             0.000000
# ...

# %%
#Quantity of samples for each cualitative characteristic (geographical information)
str_columns = df_covid.dtypes[df_covid.dtypes==object]
str_columns.pop("iso_code")
str_columns.pop("tests_units")

for index in str_columns.index:
    print(f"\nColumn: '{index}'\n", df_covid[index].value_counts())
# Out:
# Column: 'continent'
#  continent
# Africa           72562
# Europe           69686
# Asia             63809
# North America    52195
# Oceania          30552
# South America    17824
# Name: count, dtype: int64
#
# Column: 'location'
#  location
# Mexico             1275
# Argentina          1275
# Afghanistan        1273
# Niger              1273
# Nigeria            1273
#                    ...
# England            1187
# Wales              1177
# Macao               795
# Northern Cyprus     691
# Western Sahara        1
# Name: count, Length: 255, dtype: int64

# %% [markdown]
# Data Visualization using DataAnalyzer

# %%
class_instance.plot_covid_cases_by_country("Canada", "/home/juliancoss/repos_git/data-analysis_bi-project/src/static/images/time_series_covid.jpg")
